# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\users\saibaba\anaconda3\lib\site-packages (2.5)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\saibaba\anaconda3\lib\site-packages (from networkx) (5.0.6)

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\saibaba\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: packaging in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (20.1)
# Requirement already satisfied: tornado>=5.0 in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: pympler>=0.9 in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (0.9)
# Requirement already satisfied: attrs in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (20.3.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (8.2.0)
# Requirement already satisfied: cachetools>=4.0 in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (4.2.4)
# Requirement already satisfied: click<8.0,>=7.0 in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (7.1.2)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (0.7.1)
# Requirement already satisfied: validators in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (0.18.2)
# Requirement already satisfied: requests in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (2.25.1)
# Requirement already satisfied: base58 in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (2.1.1)
# Requirement already satisfied: altair>=3.2.0 in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (4.1.0)
# Requirement already satisfied: python-dateutil in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (2.8.1)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (1.2.4)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (3.1.24)
# Requirement already satisfied: numpy in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (1.18.5)
# Requirement already satisfied: astor in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (0.8.1)
# Requirement already satisfied: pyarrow in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (6.0.1)
# Requirement already satisfied: toml in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: watchdog in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (1.0.2)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (3.18.0)
# Requirement already satisfied: blinker in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (1.4)
# Requirement already satisfied: tzlocal in c:\users\saibaba\anaconda3\lib\site-packages (from streamlit) (4.1)
# Requirement already satisfied: jsonschema in c:\users\saibaba\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Requirement already satisfied: jinja2 in c:\users\saibaba\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: toolz in c:\users\saibaba\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.11.1)
# Requirement already satisfied: entrypoints in c:\users\saibaba\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\saibaba\anaconda3\lib\site-packages (from gitpython!=3.1.19->streamlit) (4.0.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\saibaba\anaconda3\lib\site-packages (from gitpython!=3.1.19->streamlit) (3.7.4.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\saibaba\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\saibaba\anaconda3\lib\site-packages (from pandas>=0.21.0->streamlit) (2021.1)
# Requirement already satisfied: ipykernel>=5.1.2 in c:\users\saibaba\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.3.4)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\saibaba\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (7.6.3)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\saibaba\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.0.5)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\saibaba\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.22.0)
# Requirement already satisfied: jupyter-client in c:\users\saibaba\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (6.1.12)
# Requirement already satisfied: backcall in c:\users\saibaba\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\saibaba\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.17.2)
# Requirement already satisfied: pygments in c:\users\saibaba\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.8.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\saibaba\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (3.0.17)
# Requirement already satisfied: colorama in c:\users\saibaba\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: decorator in c:\users\saibaba\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (5.0.6)
# Requirement already satisfied: setuptools>=18.5 in c:\users\saibaba\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (52.0.0.post20210125)
# Requirement already satisfied: pickleshare in c:\users\saibaba\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\saibaba\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\saibaba\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\saibaba\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.0.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\saibaba\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\saibaba\anaconda3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: ipython-genutils in c:\users\saibaba\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: jupyter-core in c:\users\saibaba\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.7.1)
# Requirement already satisfied: six>=1.11.0 in c:\users\saibaba\anaconda3\lib\site-packages (from jsonschema->altair>=3.2.0->streamlit) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\saibaba\anaconda3\lib\site-packages (from jsonschema->altair>=3.2.0->streamlit) (0.17.3)
# Requirement already satisfied: wcwidth in c:\users\saibaba\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\saibaba\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.3.0)
# Requirement already satisfied: argon2-cffi in c:\users\saibaba\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\saibaba\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.9.4)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\saibaba\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: nbconvert in c:\users\saibaba\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.0.7)
# Requirement already satisfied: pyzmq>=17 in c:\users\saibaba\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (20.0.0)
# Requirement already satisfied: prometheus-client in c:\users\saibaba\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.10.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\saibaba\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (227)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\saibaba\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\saibaba\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\saibaba\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.20)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\saibaba\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\saibaba\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: testpath in c:\users\saibaba\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: bleach in c:\users\saibaba\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\saibaba\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\saibaba\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\saibaba\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.3)
# Requirement already satisfied: async-generator in c:\users\saibaba\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\saibaba\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\saibaba\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\saibaba\anaconda3\lib\site-packages (from packaging->streamlit) (2.4.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\saibaba\anaconda3\lib\site-packages (from requests->streamlit) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\saibaba\anaconda3\lib\site-packages (from requests->streamlit) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saibaba\anaconda3\lib\site-packages (from requests->streamlit) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\saibaba\anaconda3\lib\site-packages (from requests->streamlit) (1.26.4)
# Requirement already satisfied: tzdata in c:\users\saibaba\anaconda3\lib\site-packages (from tzlocal->streamlit) (2021.5)
# Requirement already satisfied: backports.zoneinfo in c:\users\saibaba\anaconda3\lib\site-packages (from tzlocal->streamlit) (0.2.1)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\saibaba\anaconda3\lib\site-packages (from tzlocal->streamlit) (0.1.0.post0)

# %%
# !pip install preprocess
# Out:
# Collecting preprocess
#   Downloading preprocess-2.0.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: future in c:\users\saibaba\anaconda3\lib\site-packages (from preprocess) (0.18.2)
# Installing collected packages: preprocess
# Successfully installed preprocess-2.0.0

# %%
from sklearn.preprocessing import Binarizer, StandardScaler, OneHotEncoder

# %%
#Import libraries
import streamlit as st
import pandas as pd
import numpy as np
from PIL import Image

#load the model from disk
import joblib
model = joblib.load(r"./model.sav")

#Import python scripts
import preprocess

def main():
    #Setting Application title
    st.title('Telco Customer Churn Prediction App')

      #Setting Application description
    st.markdown("""
     :dart:  This Streamlit app is made to predict customer churn in a ficitional telecommunication use case.
    The application is functional for both online prediction and batch data prediction. \n
    """)
    st.markdown("<h3></h3>", unsafe_allow_html=True)

    #Setting Application sidebar default
    image = Image.open('App.jpg')
    add_selectbox = st.sidebar.selectbox(
    "How would you like to predict?", ("Online", "Batch"))
    st.sidebar.info('This app is created to predict Customer Churn')
    st.sidebar.image(image)

    if add_selectbox == "Online":
        st.info("Input data below")
        #Based on our optimal features selection
        st.subheader("Demographic data")
        seniorcitizen = st.selectbox('Senior Citizen:', ('Yes', 'No'))
        dependents = st.selectbox('Dependent:', ('Yes', 'No'))


        st.subheader("Payment data")
        tenure = st.slider('Number of months the customer has stayed with the company', min_value=0, max_value=72, value=0)
        contract = st.selectbox('Contract', ('Month-to-month', 'One year', 'Two year'))
        paperlessbilling = st.selectbox('Paperless Billing', ('Yes', 'No'))
        PaymentMethod = st.selectbox('PaymentMethod',('Electronic check', 'Mailed check', 'Bank transfer (automatic)','Credit card (automatic)'))
        monthlycharges = st.number_input('The amount charged to the customer monthly', min_value=0, max_value=150, value=0)
        totalcharges = st.number_input('The total amount charged to the customer',min_value=0, max_value=10000, value=0)

        st.subheader("Services signed up for")
        mutliplelines = st.selectbox("Does the customer have multiple lines",('Yes','No','No phone service'))
        phoneservice = st.selectbox('Phone Service:', ('Yes', 'No'))
        internetservice = st.selectbox("Does the customer have internet service", ('DSL', 'Fiber optic', 'No'))
        onlinesecurity = st.selectbox("Does the customer have online security",('Yes','No','No internet service'))
        onlinebackup = st.selectbox("Does the customer have online backup",('Yes','No','No internet service'))
        techsupport = st.selectbox("Does the customer have technology support", ('Yes','No','No internet service'))
        streamingtv = st.selectbox("Does the customer stream TV", ('Yes','No','No internet service'))
        streamingmovies = st.selectbox("Does the customer stream movies", ('Yes','No','No internet service'))

        data = {
                'SeniorCitizen': seniorcitizen,
                'Dependents': dependents,
                'tenure':tenure,
                'PhoneService': phoneservice,
                'MultipleLines': mutliplelines,
                'InternetService': internetservice,
                'OnlineSecurity': onlinesecurity,
                'OnlineBackup': onlinebackup,
                'TechSupport': techsupport,
                'StreamingTV': streamingtv,
                'StreamingMovies': streamingmovies,
                'Contract': contract,
                'PaperlessBilling': paperlessbilling,
                'PaymentMethod':PaymentMethod, 
                'MonthlyCharges': monthlycharges, 
                'TotalCharges': totalcharges
                }
        features_df = pd.DataFrame.from_dict([data])
        st.markdown("<h3></h3>", unsafe_allow_html=True)
        st.write('Overview of input is shown below')
        st.markdown("<h3></h3>", unsafe_allow_html=True)
        st.dataframe(features_df)


        #Preprocess inputs
        preprocess_df = preprocess(features_df, 'Online')

        prediction = model.predict(preprocess_df)

        if st.button('Predict'):
            if prediction == 1:
                st.warning('Yes, the customer will terminate the service.')
            else:
                st.success('No, the customer is happy with Telco Services.')
        

    else:
        st.subheader("Dataset upload")
        uploaded_file = st.file_uploader("Choose a file")
        if uploaded_file is not None:
            data = pd.read_csv(uploaded_file)
            #Get overview of data
            st.write(data.head())
            st.markdown("<h3></h3>", unsafe_allow_html=True)
            #Preprocess inputs
            preprocess_df = preprocess(data, "Batch")
            if st.button('Predict'):
                #Get batch prediction
                prediction = model.predict(preprocess_df)
                prediction_df = pd.DataFrame(prediction, columns=["Predictions"])
                prediction_df = prediction_df.replace({1:'Yes, the customer will terminate the service.', 
                                                    0:'No, the customer is happy with Telco Services.'})

                st.markdown("<h3></h3>", unsafe_allow_html=True)
                st.subheader('Prediction')
                st.write(prediction_df)
            
if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-dee22f0d990e> in <module>
#     115
#     116 if __name__ == '__main__':
# --> 117     main()
#
# <ipython-input-28-dee22f0d990e> in main()
#      82
#      83         #Preprocess inputs
# ---> 84         preprocess_df = preprocess(features_df, 'Online')
#      85
#      86         prediction = model.predict(preprocess_df)
#
# TypeError: 'module' object is not callable
